# %%
from model import * 
from data_processing import *

# %%
# generate spectrograms

generate_spectrograms(0.3,"dell","FFT")
# Out:
# Summary of the keystroke data :
# Total valid keystrokes: 1096
# Total invalid keystrokes: 11
# Keystroke times:
# Average time between two keys  0.13219127945205475
# Average keystroke duration:  0.10812529379562047
# 1096  keys to process
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/GitHub/MAIS202-FinalProject/venv/lib/python3.12/site-packages/PIL/ImageFile.py:554, in _save(im, fp, tile, bufsize)
#     553 try:
# --> 554     fh = fp.fileno()
#     555     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # generate spectrograms
# ----> 3 generate_spectrograms(0.3,"dell","FFT")
#
# ...

# %%
features,labels,_ = load_spectrograms_from_directory("dell/numpy_arrays")

encoded_labels = key_to_idx_tensors(labels)

# %%
model = KeystrokeCNN()

criterion = nn.CrossEntropyLoss()

losses, *t = train(model,features,encoded_labels,0.01,3,"dell",0.001)

print("results from the training",losses)
# Out:
# [1, 10] loss: 1233.817
# The input tensors do not match the model's parameters (width/height)
#  Expected torch.Size([64, 1, 129, 300]) but got torch.Size([59, 1, 129, 300])
# skipping incorrect vector
# [1, 20] loss: 3.255
# Epoch 1 average loss: 618.536
# [2, 10] loss: 3.216
# The input tensors do not match the model's parameters (width/height)
#  Expected torch.Size([64, 1, 129, 300]) but got torch.Size([59, 1, 129, 300])
# skipping incorrect vector
# [2, 20] loss: 3.148
# Epoch 2 average loss: 3.182
# [3, 10] loss: 3.107
# The input tensors do not match the model's parameters (width/height)
#  Expected torch.Size([64, 1, 129, 300]) but got torch.Size([59, 1, 129, 300])
# skipping incorrect vector
# [3, 20] loss: 3.107
# Epoch 3 average loss: 3.107
# results from the training
